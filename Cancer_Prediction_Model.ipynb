# %% [markdown]
# <a href="https://colab.research.google.com/github/lounedeli/Machine-Learning-Data-Analytics/blob/main/Cancer_Prediction_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This Machine Learning Model will look through a diagnostic description dataset and make a prediction as to whether or not the given information represents high likeliness for a cancer diagnosis.

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import our dataset

cancer_df = pd.read_csv("/content/Cancer_Data.csv")
cancer_df.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760         0.30010              0.14710
# 1          0.08474           0.07864         0.08690              0.07017
# 2          0.10960           0.15990         0.19740              0.12790
# 3          0.14250           0.28390         0.24140              0.10520
# 4          0.10030           0.13280         0.19800              0.10430
# 5          0.12780           0.17000         0.15780              0.08089
# 6          0.09463           0.10900         0.11270              0.07400
# 7          0.11890           0.16450         0.09366              0.05985
# 8          0.12730           0.19320         0.18590              0.09353
# 9          0.11860           0.23960         0.22730              0.08543
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
# 5  ...          23.75           103.40       741.6            0.1791
# 6  ...          27.66           153.20      1606.0            0.1442
# 7  ...          28.14           110.60       897.0            0.1654
# 8  ...          30.73           106.20       739.3            0.1703
# 9  ...          40.68            97.65       711.4            0.1853
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
# 5             0.5249           0.5355                0.1741          0.3985
# 6             0.2576           0.3784                0.1932          0.3063
# 7             0.3682           0.2678                0.1556          0.3196
# 8             0.5401           0.5390                0.2060          0.4378
# 9             1.0580           1.1050                0.2210          0.4366
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
# 5                  0.12440          NaN
# 6                  0.08368          NaN
# 7                  0.11510          NaN
# 8                  0.10720          NaN
# 9                  0.20750          NaN
#
# [10 rows x 33 columns]

# %%
cancer_df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  ...  texture_worst  perimeter_worst   area_worst  \
# count     569.000000  ...     569.000000       569.000000   569.000000
# mean        0.181162  ...      25.677223       107.261213   880.583128
# std         0.027414  ...       6.146258        33.602542   569.356993
# min         0.106000  ...      12.020000        50.410000   185.200000
# 25%         0.161900  ...      21.080000        84.110000   515.300000
# 50%         0.179200  ...      25.410000        97.660000   686.500000
# 75%         0.195700  ...      29.720000       125.400000  1084.000000
# max         0.304000  ...      49.540000       251.200000  4254.000000
#
#        smoothness_worst  compactness_worst  concavity_worst  \
# count        569.000000         569.000000       569.000000
# mean           0.132369           0.254265         0.272188
# std            0.022832           0.157336         0.208624
# min            0.071170           0.027290         0.000000
# 25%            0.116600           0.147200         0.114500
# 50%            0.131300           0.211900         0.226700
# 75%            0.146000           0.339100         0.382900
# max            0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst  \
# count            569.000000      569.000000               569.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065732        0.061867                 0.018061
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
#        Unnamed: 32
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN
#
# [8 rows x 32 columns]

# %% [markdown]
# # Dataset Info

# %%
#number of rows and columns
cancer_df.shape
# Out:
# (569, 33)

# %%
#all of our dataset's feature listed here
cancer_df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %% [markdown]
# # Our target variable is 'diagnosis'.
# # We have 33 columns or 'features'
# # Within this dataset, diagnosis is either 'M' for malignant or 'B' for benign.
# # We will work through this as a binary classification problem.

# %%
#let's check how many benign and malignant diagnoses there are
cancer_df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# # We have a total of 357 Benign diagnoses and 212 Malignant ones within this dataset.

# %% [markdown]
# # Checking for null values

# %%
cancer_df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %% [markdown]
# # No null values, however Unnamed: 32 column seems to have all NaN values, so it will be removed from training data

# %% [markdown]
# # Let's change the diagnostic data into numerical format to be able to more easily plot and explore the data

# %%
cancer_df['diagnosis'].replace(['B', 'M'], [0, 1], inplace = True)

# %%
# B --> 0, M --> 1
cancer_df['diagnosis'].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# # Exploratory Analysis

# %%
# Using a categorical scatter plot to give a clear look into the effect of radius mean on diagnoses
#based on diagnosis from 0 to one and radius mean

plt.figure(figsize=(10,6))
sns.set_style("whitegrid")
plt.title("Benign vs Malignant Diagnoses against Radius Mean")

sns.swarmplot(x = cancer_df['diagnosis'], y = cancer_df['radius_mean'])
# Out:
# <Axes: title={'center': 'Benign vs Malignant Diagnoses against Radius Mean'}, xlabel='diagnosis', ylabel='radius_mean'>

# %% [markdown]
# # Looking at the diagnoses as compared to the radius mean, we can see that on average, masses diagnosed as malignent tend to have a higher radius mean than those diagnosed as benign.
# #We see this in the following table, where 'radius_mean' is significantly higher in malignant masses:

# %%
cancer_df.groupby('diagnosis')[['radius_mean']].mean()
# Out:
#            radius_mean
# diagnosis
# 0            12.146524
# 1            17.462830

# %%
M = cancer_df[cancer_df.diagnosis == 1] #Diagnosis transfers all values of M to M data
B = cancer_df[cancer_df.diagnosis == 0] #Diagnosis transfers all values of B to B data

plt.scatter(M.smoothness_mean,M.compactness_mean, label = "Malignant", alpha = 0.3)
plt.scatter(B.smoothness_mean,B.compactness_mean,label = "Benign", alpha = 0.3)

plt.xlabel("smoothness_mean")
plt.ylabel("compactness_mean")

plt.legend()
plt.show()

# %% [markdown]
# # From the plot we can see that Benign cells are much less compact and much less smooth than Malignant cells. There is some crossover however.

# %%
cancer_df.groupby('diagnosis')[['smoothness_mean','compactness_mean']].mean()
# Out:
#            smoothness_mean  compactness_mean
# diagnosis
# 0                 0.092478          0.080085
# 1                 0.102898          0.145188

# %% [markdown]
# # Smoothness mean for both benign and malignant seem to have less correlation to each other. However, compactness is much higher in malignant cells throughout.

# %% [markdown]
# # Model Building with SGD

# %%
#first drop Unnamed and id column for accurate training data
cancer_df = cancer_df.drop(labels="Unnamed: 32", axis=1)
cancer_df = cancer_df.drop(labels="id", axis=1)

# %%
cancer_df.shape
# Out:
# (569, 31)

# %%
cancer_df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split

X, y = cancer_df.drop('diagnosis', axis=1), cancer_df[['diagnosis']]

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.33, random_state=43, stratify=y)

# %%
#import and build out model
from tensorflow import keras
from tensorflow.keras import layers

#changed unit amount from 512 to 64
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=[30]),
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation = 'sigmoid'),
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

early_stopping = keras.callbacks.EarlyStopping(
    patience=10,
    min_delta=0.001,
    restore_best_weights=True,
)

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    batch_size=128,
    epochs=200,
    callbacks=[early_stopping],
    verbose=1, # hide the output because we have so many epochs
)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 2s 163ms/step - loss: 3.5029 - binary_accuracy: 0.7060 - val_loss: 1.2487 - val_binary_accuracy: 0.6755
# Epoch 2/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.2740 - binary_accuracy: 0.6037 - val_loss: 0.6997 - val_binary_accuracy: 0.8032
# Epoch 3/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.8974 - binary_accuracy: 0.8583 - val_loss: 1.1960 - val_binary_accuracy: 0.8457
# Epoch 4/200
# 3/3 [==============================] - 0s 29ms/step - loss: 1.2625 - binary_accuracy: 0.8583 - val_loss: 0.3466 - val_binary_accuracy: 0.9149
# Epoch 5/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.6228 - binary_accuracy: 0.8688 - val_loss: 0.8683 - val_binary_accuracy: 0.7766
# Epoch 6/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6639 - binary_accuracy: 0.8189 - val_loss: 0.3002 - val_binary_accuracy: 0.9043
# Epoch 7/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.5171 - binary_accuracy: 0.9108 - val_loss: 0.5052 - val_binary_accuracy: 0.9202
# Epoch 8/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.5070 - binary_accuracy: 0.9134 - val_loss: 0.2405 - val_binary_accuracy: 0.9043
# Epoch 9/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.3920 - binary_accuracy: 0.8793 - val_loss: 0.3532 - val_binary_accuracy: 0.8989
# Epoch 10/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2466 - binary_accuracy: 0.9239 - val_loss: 0.3219 - val_binary_accuracy: 0.9202
# Epoch 11/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3266 - binary_accuracy: 0.9134 - val_loss: 0.2295 - val_binary_accuracy: 0.9255
# Epoch 12/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.2544 - binary_accuracy: 0.9055 - val_loss: 0.2919 - val_binary_accuracy: 0.8936
# Epoch 13/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.2109 - binary_accuracy: 0.9213 - val_loss: 0.2413 - val_binary_accuracy: 0.9255
# Epoch 14/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.2410 - binary_accuracy: 0.9291 - val_loss: 0.2373 - val_binary_accuracy: 0.9255
# Epoch 15/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.2294 - binary_accuracy: 0.9213 - val_loss: 0.2591 - val_binary_accuracy: 0.8883
# Epoch 16/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.2100 - binary_accuracy: 0.9318 - val_loss: 0.2257 - val_binary_accuracy: 0.9309
# Epoch 17/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2163 - binary_accuracy: 0.9318 - val_loss: 0.2135 - val_binary_accuracy: 0.9255
# Epoch 18/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.2163 - binary_accuracy: 0.9265 - val_loss: 0.2346 - val_binary_accuracy: 0.8936
# Epoch 19/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1895 - binary_accuracy: 0.9370 - val_loss: 0.2327 - val_binary_accuracy: 0.9309
# Epoch 20/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.2037 - binary_accuracy: 0.9396 - val_loss: 0.2078 - val_binary_accuracy: 0.9149
# Epoch 21/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1865 - binary_accuracy: 0.9423 - val_loss: 0.2287 - val_binary_accuracy: 0.8936
# Epoch 22/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1935 - binary_accuracy: 0.9291 - val_loss: 0.2111 - val_binary_accuracy: 0.9255
# Epoch 23/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1868 - binary_accuracy: 0.9396 - val_loss: 0.2041 - val_binary_accuracy: 0.9202
# Epoch 24/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1780 - binary_accuracy: 0.9423 - val_loss: 0.2099 - val_binary_accuracy: 0.9043
# Epoch 25/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1857 - binary_accuracy: 0.9396 - val_loss: 0.2014 - val_binary_accuracy: 0.9202
# Epoch 26/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1836 - binary_accuracy: 0.9344 - val_loss: 0.2026 - val_binary_accuracy: 0.9149
# Epoch 27/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1740 - binary_accuracy: 0.9396 - val_loss: 0.2010 - val_binary_accuracy: 0.9255
# Epoch 28/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1860 - binary_accuracy: 0.9370 - val_loss: 0.2038 - val_binary_accuracy: 0.9096
# Epoch 29/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1778 - binary_accuracy: 0.9370 - val_loss: 0.2009 - val_binary_accuracy: 0.9096
# Epoch 30/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1850 - binary_accuracy: 0.9423 - val_loss: 0.1976 - val_binary_accuracy: 0.9149
# Epoch 31/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1711 - binary_accuracy: 0.9370 - val_loss: 0.2026 - val_binary_accuracy: 0.9043
# Epoch 32/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1797 - binary_accuracy: 0.9370 - val_loss: 0.1955 - val_binary_accuracy: 0.9149
# Epoch 33/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1713 - binary_accuracy: 0.9370 - val_loss: 0.1983 - val_binary_accuracy: 0.9096
# Epoch 34/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1754 - binary_accuracy: 0.9396 - val_loss: 0.1951 - val_binary_accuracy: 0.9255
# Epoch 35/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1761 - binary_accuracy: 0.9423 - val_loss: 0.1950 - val_binary_accuracy: 0.9202
# Epoch 36/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1724 - binary_accuracy: 0.9396 - val_loss: 0.1942 - val_binary_accuracy: 0.9202
# Epoch 37/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1753 - binary_accuracy: 0.9423 - val_loss: 0.1942 - val_binary_accuracy: 0.9202
# Epoch 38/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1710 - binary_accuracy: 0.9396 - val_loss: 0.1979 - val_binary_accuracy: 0.9043
# Epoch 39/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1659 - binary_accuracy: 0.9423 - val_loss: 0.1986 - val_binary_accuracy: 0.9202
# Epoch 40/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1676 - binary_accuracy: 0.9396 - val_loss: 0.2015 - val_binary_accuracy: 0.9096
# Epoch 41/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1719 - binary_accuracy: 0.9423 - val_loss: 0.1939 - val_binary_accuracy: 0.9149
# Epoch 42/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1649 - binary_accuracy: 0.9370 - val_loss: 0.1940 - val_binary_accuracy: 0.9096
# Epoch 43/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1647 - binary_accuracy: 0.9370 - val_loss: 0.1918 - val_binary_accuracy: 0.9149
# Epoch 44/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1633 - binary_accuracy: 0.9370 - val_loss: 0.1916 - val_binary_accuracy: 0.9202
# Epoch 45/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1663 - binary_accuracy: 0.9344 - val_loss: 0.1927 - val_binary_accuracy: 0.9149
# Epoch 46/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1777 - binary_accuracy: 0.9291 - val_loss: 0.1903 - val_binary_accuracy: 0.9202
# Epoch 47/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1646 - binary_accuracy: 0.9396 - val_loss: 0.1945 - val_binary_accuracy: 0.9149
# Epoch 48/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1699 - binary_accuracy: 0.9396 - val_loss: 0.1903 - val_binary_accuracy: 0.9202
# Epoch 49/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1659 - binary_accuracy: 0.9396 - val_loss: 0.1901 - val_binary_accuracy: 0.9202
# Epoch 50/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1683 - binary_accuracy: 0.9344 - val_loss: 0.1921 - val_binary_accuracy: 0.9202
# Epoch 51/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1709 - binary_accuracy: 0.9396 - val_loss: 0.2347 - val_binary_accuracy: 0.8883
# Epoch 52/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1746 - binary_accuracy: 0.9370 - val_loss: 0.2076 - val_binary_accuracy: 0.9309
# Epoch 53/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1901 - binary_accuracy: 0.9318 - val_loss: 0.1986 - val_binary_accuracy: 0.9149
# Epoch 54/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1691 - binary_accuracy: 0.9370 - val_loss: 0.1885 - val_binary_accuracy: 0.9149
# Epoch 55/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1634 - binary_accuracy: 0.9449 - val_loss: 0.1901 - val_binary_accuracy: 0.9255
# Epoch 56/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1676 - binary_accuracy: 0.9475 - val_loss: 0.2256 - val_binary_accuracy: 0.8989
# Epoch 57/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1950 - binary_accuracy: 0.9396 - val_loss: 0.1875 - val_binary_accuracy: 0.9255
# Epoch 58/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1616 - binary_accuracy: 0.9423 - val_loss: 0.1896 - val_binary_accuracy: 0.9149
# Epoch 59/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1589 - binary_accuracy: 0.9396 - val_loss: 0.1930 - val_binary_accuracy: 0.9255
# Epoch 60/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1840 - binary_accuracy: 0.9291 - val_loss: 0.2168 - val_binary_accuracy: 0.8989
# Epoch 61/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1785 - binary_accuracy: 0.9449 - val_loss: 0.2071 - val_binary_accuracy: 0.9309
# Epoch 62/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1831 - binary_accuracy: 0.9344 - val_loss: 0.1969 - val_binary_accuracy: 0.9149
# Epoch 63/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1671 - binary_accuracy: 0.9475 - val_loss: 0.1894 - val_binary_accuracy: 0.9202
# Epoch 64/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1580 - binary_accuracy: 0.9449 - val_loss: 0.1910 - val_binary_accuracy: 0.9149

# %% [markdown]
# # Checking for Noise, Over/Underfitting

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot();
print("Minimum validation loss: {}".format(history_df['val_loss'].min()))
# Out:
# Minimum validation loss: 0.18754012882709503

# %% [markdown]
# # We've gotten our model to about 91% accuracy on our validation data by lowering our units from 512 to 64, as well as lowering epoch and batch size.
